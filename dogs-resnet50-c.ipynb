# %%
# import all libraries here
import os
import pathlib
import xml.etree.ElementTree as ET
from PIL import Image
import multiprocessing as mp
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *
import datetime as dt
from tensorflow.keras import backend as K
from keras.applications.resnet50 import ResNet50

print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.2.0
# 2.3.0-tf

# %%
TEST_SIZE = 0.2
RANDOM_SEED = 28

targetx = 224
targety = 224

batch_size = 8

learning_rate =  0.0001

np.random.seed(RANDOM_SEED)

# %%
ANNOTATION_DIR = pathlib.Path('../input/stanford-dogs-dataset/annotations/Annotation')
IMAGES_DIR = pathlib.Path('../input/stanford-dogs-dataset/images/Images')

BREED_DIR = [path for path in IMAGES_DIR.iterdir()]
BREED_DIR_NAME = [path.name for path in BREED_DIR]

BREED_CODE_TO_NAME = {breed.split('-')[0]: breed.split('-')[1] for breed in BREED_DIR_NAME}


BREED_CODE_TO_NAME = {breed.split('-')[0]: breed.split('-')[1] for breed in BREED_DIR_NAME}


BREED_NAME_TO_CODE = {v: k for k, v in BREED_CODE_TO_NAME.items()}


BREED_LABEL_TO_CODE = {i: code for i, code in enumerate(BREED_CODE_TO_NAME)}


BREED_CODE_TO_LABEL = {v: k for k, v in BREED_LABEL_TO_CODE.items()}


BREED_LABEL_TO_NAME = {i: BREED_CODE_TO_NAME[code] for i, code in BREED_LABEL_TO_CODE.items()}


BREED_NAME_TO_LABEL = {v: k for k, v in BREED_LABEL_TO_NAME.items()}

# %%
def path_to_label(path):
    code = path.stem.split('_')[0]
    return BREED_CODE_TO_LABEL[code]

def get_all_file_path(directory, file_pattern=''):
    paths = list(f for f in directory.rglob('**/*{}'.format(file_pattern)) if f.is_file())
    return sorted(paths, key=str)

# %%
all_image_paths = get_all_file_path(IMAGES_DIR, '.jpg') # PosixPath

all_image_labels = [path_to_label(path) for path in all_image_paths]

assert len(all_image_paths)==len(all_image_labels), 'Numbers of images and labels not match! {}!={}'.format(len(all_image_paths), len(all_image_labels))

# %%
with open('labels.txt', 'w') as f:
    f.write('\n'.join(BREED_NAME_TO_LABEL))# Write labels to file

# %%
# Crop and save images according to boundings

# making a directory to save cropped images
IMAGES_CROPPED_DIR = pathlib.Path('/kaggle/working/images_cropped/')
IMAGES_CROPPED_DIR.mkdir(parents=True, exist_ok=True) 
print('done')
# Out:
# done

# %%
# Gets object boundings
def parse_bounding(path):
    # Get annotation path from image path
    path = ANNOTATION_DIR / path.parent.name / path.stem
    
    # Parse boundings
    tree = ET.parse(path)
    bndbox = tree.getroot().findall('object')[0].find('bndbox')
    left = int(bndbox.find('xmin').text)
    right = int(bndbox.find('xmax').text) 
    upper = int(bndbox.find('ymin').text)
    lower = int(bndbox.find('ymax').text) 
    
    return (left, upper, right, lower)

# %%
def crop_and_save_image(path, save_dir=IMAGES_CROPPED_DIR):
    box = parse_bounding(path)
    
    image = Image.open(path)
    image_cropped = image.crop(box)
    image_cropped = image_cropped.convert('RGB')
    image_cropped.save(save_dir / path.name)

# %%
# %%time
try:
    pool = mp.Pool(processes=mp.cpu_count())
    pool.map(crop_and_save_image, all_image_paths)
except Exception as e:
    print(e)
finally:
    pool.close()
# Out:
# CPU times: user 212 ms, sys: 75.2 ms, total: 288 ms
# Wall time: 4min 10s

# %%
all_image_cropped_paths = get_all_file_path(IMAGES_CROPPED_DIR, '.jpg') # PosixPath
all_image_cropped_labels = [path_to_label(path) for path in all_image_cropped_paths] # [0,1,2,...]

assert len(all_image_paths)==len(all_image_cropped_paths), 'Numbers of images and cropped images not match! {}!={}'.format(len(all_image_paths), len(all_image_cropped_paths))

# %%
IMAGE_PATH = all_image_cropped_paths
LABEL = all_image_cropped_labels

# %%
# Label distribution
_ = plt.hist(LABEL, bins=120)
plt.xlabel('Label index')
plt.ylabel('Count')
plt.title('Label Distribution')
plt.show()

# %%
# Ramdomly check a dog image from the dataset
dog = np.random.choice(IMAGE_PATH)
print('Random dog: ', BREED_LABEL_TO_NAME[path_to_label(dog)])
Image.open(dog)
# Out:
# Random dog:  West_Highland_white_terrier
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=173x197 at 0x7F0AF1B4D8D0>

# %%
# splitting into training and test set
x_train, x_test, y_train, y_test = train_test_split(IMAGE_PATH, 
                                                    LABEL,
                                                    test_size=TEST_SIZE, 
                                                    random_state=RANDOM_SEED,
                                                    shuffle=True,
                                                    stratify=LABEL)

print('Train data: ', len(x_train))
print('Test data: ', len(x_test))
# Out:
# Train data:  16464
# Test data:  4116

# %%
classes = BREED_NAME_TO_CODE.keys()
TRAIN_DIR = pathlib.Path('/kaggle/working/train_dir/')
TRAIN_DIR.mkdir(parents=True, exist_ok=True)

VALIDATION_DIR = pathlib.Path('/kaggle/working/val_dir/')
VALIDATION_DIR.mkdir(parents=True, exist_ok=True)

# %%
# %%time
def make_classes_folder(folder_path):
    for c in classes:
        path = folder_path / c
        path.mkdir()
        
make_classes_folder(TRAIN_DIR)
make_classes_folder(VALIDATION_DIR)
# Out:
# CPU times: user 5.62 ms, sys: 4.89 ms, total: 10.5 ms
# Wall time: 10.4 ms

# %%
# %%time
def copy_img_to_folder(path_array,folder_path):
    for img_path in path_array:
        code_to_label = BREED_CODE_TO_NAME.get(img_path.stem.split('_')[0])
        image = Image.open(img_path)
        image.save(folder_path / code_to_label / img_path.name)


copy_img_to_folder(x_train,TRAIN_DIR)

copy_img_to_folder(x_test,VALIDATION_DIR)
# Out:
# CPU times: user 3min 25s, sys: 2.03 s, total: 3min 27s
# Wall time: 3min 29s

# %%
datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        fill_mode = 'nearest',
        validation_split=TEST_SIZE
        #preprocessing_function=preprocess_input
)

train_generator = datagen.flow_from_directory(
        TRAIN_DIR,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=RANDOM_SEED,
        subset="training"
)


test_generator = datagen.flow_from_directory(
        VALIDATION_DIR,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=RANDOM_SEED,
        subset="validation"
)
# Out:
# Found 13210 images belonging to 120 classes.
# Found 786 images belonging to 120 classes.

# %%
checkpoint = ModelCheckpoint('dog_breed_classifier.h5',
                             monitor='val_accuracy',
                             save_best_only=True,
                             verbose=1,
                             mode='auto',
                             save_weights_only=False,
                             period=1)

tensorboard = TensorBoard(log_dir="./logs-"+dt.datetime.now().strftime("%m%d%Y%H%M%S"),
                            histogram_freq=0,
                            batch_size=batch_size,
                            write_graph=False,
                            update_freq='epoch')

def epoch_end(epoch, logs):
    message = "End of epoch "+str(epoch)+". Learning rate: "+str(K.eval(model.optimizer.lr))
    os.system('echo '+message)

def epoch_begin(epoch, logs):
    print("Learning rate: ", K.eval(model.optimizer.lr))
    
def train_begin(logs):
    os.system("echo Beginning training")

earlystop = EarlyStopping(monitor='val_accuracy',
                          min_delta=.0001,
                          patience=20,
                          verbose=1,
                          mode='auto',
                          baseline=None,
                          restore_best_weights=True)

reducelr = ReduceLROnPlateau(monitor='val_accuracy',
                             factor=np.sqrt(.1),
                             patience=5,
                             verbose=1,
                             mode='auto',
                             min_delta=.0001,
                             cooldown=0,
                             min_lr=0.0000001)

lambdacb = LambdaCallback(on_epoch_begin=epoch_begin,
                          on_epoch_end=epoch_end,
                          on_batch_begin=None,
                          on_batch_end=None,
                          on_train_begin=train_begin,
                          on_train_end=None)

# %%
# %%time
base_model = ResNet50(include_top=False, weights='imagenet', input_shape=(targetx,targety,3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation="relu",kernel_initializer=glorot_uniform(RANDOM_SEED), bias_initializer='zeros')(x)
x = Dense(64, activation="relu",kernel_initializer=glorot_uniform(RANDOM_SEED), bias_initializer='zeros')(x)
predictions = Dense(len(classes), activation='softmax', kernel_initializer='random_uniform', bias_initializer='zeros')(x)
model = Model(inputs=base_model.input, outputs=predictions)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# CPU times: user 3.94 s, sys: 988 ms, total: 4.93 s
# Wall time: 6.84 s

# %%
# %%time
optimizer = Adam(lr=learning_rate)
loss = "categorical_crossentropy"
e = 40

for layer in model.layers:
    layer.trainable = True
    
model.compile(optimizer=optimizer,
              loss=loss,
              metrics=["accuracy"])

#model.summary()

params = model.fit_generator(generator=train_generator, 
                                steps_per_epoch=len(train_generator)//batch_size, 
                                validation_data=test_generator, 
                                validation_steps=len(test_generator)//batch_size,
                                epochs=e,
                                callbacks=[reducelr,earlystop, lambdacb, tensorboard, checkpoint])
# Out:
# Learning rate:  1e-04
# Epoch 1/40
# 206/206 [==============================] - ETA: 0s - loss: 4.6485 - accuracy: 0.0322
# Epoch 00001: val_accuracy improved from -inf to 0.04167, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 38s 184ms/step - loss: 4.6485 - accuracy: 0.0322 - val_loss: 5.2821 - val_accuracy: 0.0417 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 2/40
# 206/206 [==============================] - ETA: 0s - loss: 4.0887 - accuracy: 0.1068
# Epoch 00002: val_accuracy improved from 0.04167 to 0.14583, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 36s 176ms/step - loss: 4.0887 - accuracy: 0.1068 - val_loss: 3.6027 - val_accuracy: 0.1458 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 3/40
# 206/206 [==============================] - ETA: 0s - loss: 3.3596 - accuracy: 0.1967
# Epoch 00003: val_accuracy improved from 0.14583 to 0.23958, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 37s 181ms/step - loss: 3.3596 - accuracy: 0.1967 - val_loss: 3.1867 - val_accuracy: 0.2396 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 4/40
# 206/206 [==============================] - ETA: 0s - loss: 2.9458 - accuracy: 0.2512
# Epoch 00004: val_accuracy improved from 0.23958 to 0.27083, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 36s 174ms/step - loss: 2.9458 - accuracy: 0.2512 - val_loss: 2.8659 - val_accuracy: 0.2708 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 5/40
# 206/206 [==============================] - ETA: 0s - loss: 2.6397 - accuracy: 0.3058
# Epoch 00005: val_accuracy improved from 0.27083 to 0.31250, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 36s 175ms/step - loss: 2.6397 - accuracy: 0.3058 - val_loss: 2.6681 - val_accuracy: 0.3125 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 6/40
# 206/206 [==============================] - ETA: 0s - loss: 2.3741 - accuracy: 0.3508
# Epoch 00006: val_accuracy improved from 0.31250 to 0.47917, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 36s 175ms/step - loss: 2.3741 - accuracy: 0.3508 - val_loss: 2.0648 - val_accuracy: 0.4792 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 7/40
# 206/206 [==============================] - ETA: 0s - loss: 2.2413 - accuracy: 0.3877
# Epoch 00007: val_accuracy did not improve from 0.47917
# 206/206 [==============================] - 34s 166ms/step - loss: 2.2413 - accuracy: 0.3877 - val_loss: 2.0658 - val_accuracy: 0.3438 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 8/40
# 206/206 [==============================] - ETA: 0s - loss: 2.0851 - accuracy: 0.4123
# Epoch 00008: val_accuracy did not improve from 0.47917
# 206/206 [==============================] - 35s 168ms/step - loss: 2.0851 - accuracy: 0.4123 - val_loss: 1.9768 - val_accuracy: 0.4479 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 9/40
# 206/206 [==============================] - ETA: 0s - loss: 1.9441 - accuracy: 0.4502
# Epoch 00009: val_accuracy did not improve from 0.47917
# 206/206 [==============================] - 34s 163ms/step - loss: 1.9441 - accuracy: 0.4502 - val_loss: 1.5571 - val_accuracy: 0.4688 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 10/40
# 206/206 [==============================] - ETA: 0s - loss: 1.8528 - accuracy: 0.4745
# Epoch 00010: val_accuracy did not improve from 0.47917
# 206/206 [==============================] - 35s 169ms/step - loss: 1.8528 - accuracy: 0.4745 - val_loss: 2.3473 - val_accuracy: 0.4167 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 11/40
# 206/206 [==============================] - ETA: 0s - loss: 1.7409 - accuracy: 0.5164
# Epoch 00011: val_accuracy improved from 0.47917 to 0.60417, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 35s 171ms/step - loss: 1.7409 - accuracy: 0.5164 - val_loss: 1.4802 - val_accuracy: 0.6042 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 12/40
# 206/206 [==============================] - ETA: 0s - loss: 1.6210 - accuracy: 0.5219
# Epoch 00012: val_accuracy did not improve from 0.60417
# 206/206 [==============================] - 34s 167ms/step - loss: 1.6210 - accuracy: 0.5219 - val_loss: 1.6453 - val_accuracy: 0.4896 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 13/40
# 206/206 [==============================] - ETA: 0s - loss: 1.5335 - accuracy: 0.5463
# Epoch 00013: val_accuracy did not improve from 0.60417
# 206/206 [==============================] - 35s 168ms/step - loss: 1.5335 - accuracy: 0.5463 - val_loss: 1.5932 - val_accuracy: 0.5521 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 14/40
# 206/206 [==============================] - ETA: 0s - loss: 1.5153 - accuracy: 0.5461
# Epoch 00014: val_accuracy did not improve from 0.60417
# 206/206 [==============================] - 34s 165ms/step - loss: 1.5153 - accuracy: 0.5461 - val_loss: 1.4346 - val_accuracy: 0.5312 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 15/40
# 206/206 [==============================] - ETA: 0s - loss: 1.3867 - accuracy: 0.5928
# Epoch 00015: val_accuracy improved from 0.60417 to 0.62500, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 36s 174ms/step - loss: 1.3867 - accuracy: 0.5928 - val_loss: 1.3016 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 16/40
# 206/206 [==============================] - ETA: 0s - loss: 1.4010 - accuracy: 0.6074
# Epoch 00016: val_accuracy improved from 0.62500 to 0.64583, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 35s 172ms/step - loss: 1.4010 - accuracy: 0.6074 - val_loss: 1.2950 - val_accuracy: 0.6458 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 17/40
# 206/206 [==============================] - ETA: 0s - loss: 1.2933 - accuracy: 0.5916
# Epoch 00017: val_accuracy did not improve from 0.64583
# 206/206 [==============================] - 35s 170ms/step - loss: 1.2933 - accuracy: 0.5916 - val_loss: 1.3440 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 18/40
# 206/206 [==============================] - ETA: 0s - loss: 1.2149 - accuracy: 0.6462
# Epoch 00018: val_accuracy did not improve from 0.64583
# 206/206 [==============================] - 35s 170ms/step - loss: 1.2149 - accuracy: 0.6462 - val_loss: 1.3491 - val_accuracy: 0.6354 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 19/40
# 206/206 [==============================] - ETA: 0s - loss: 1.1730 - accuracy: 0.6535
# Epoch 00019: val_accuracy improved from 0.64583 to 0.69792, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 36s 172ms/step - loss: 1.1730 - accuracy: 0.6535 - val_loss: 1.4635 - val_accuracy: 0.6979 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 20/40
# 206/206 [==============================] - ETA: 0s - loss: 1.2239 - accuracy: 0.6262
# Epoch 00020: val_accuracy did not improve from 0.69792
# 206/206 [==============================] - 34s 167ms/step - loss: 1.2239 - accuracy: 0.6262 - val_loss: 1.5852 - val_accuracy: 0.5938 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 21/40
# 206/206 [==============================] - ETA: 0s - loss: 1.0961 - accuracy: 0.6723
# Epoch 00021: val_accuracy did not improve from 0.69792
# 206/206 [==============================] - 34s 165ms/step - loss: 1.0961 - accuracy: 0.6723 - val_loss: 1.5608 - val_accuracy: 0.5938 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 22/40
# 206/206 [==============================] - ETA: 0s - loss: 1.1319 - accuracy: 0.6735
# Epoch 00022: val_accuracy improved from 0.69792 to 0.75000, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 36s 174ms/step - loss: 1.1319 - accuracy: 0.6735 - val_loss: 0.9525 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 23/40
# 206/206 [==============================] - ETA: 0s - loss: 1.0427 - accuracy: 0.6796
# Epoch 00023: val_accuracy did not improve from 0.75000
# 206/206 [==============================] - 35s 168ms/step - loss: 1.0427 - accuracy: 0.6796 - val_loss: 1.1410 - val_accuracy: 0.7083 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 24/40
# 206/206 [==============================] - ETA: 0s - loss: 1.0504 - accuracy: 0.6808
# Epoch 00024: val_accuracy did not improve from 0.75000
# 206/206 [==============================] - 34s 165ms/step - loss: 1.0504 - accuracy: 0.6808 - val_loss: 1.7463 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 25/40
# 206/206 [==============================] - ETA: 0s - loss: 1.0771 - accuracy: 0.6638
# Epoch 00025: val_accuracy did not improve from 0.75000
# 206/206 [==============================] - 34s 165ms/step - loss: 1.0771 - accuracy: 0.6638 - val_loss: 1.0007 - val_accuracy: 0.7083 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 26/40
# 206/206 [==============================] - ETA: 0s - loss: 1.0245 - accuracy: 0.6893
# Epoch 00026: val_accuracy did not improve from 0.75000
# 206/206 [==============================] - 34s 164ms/step - loss: 1.0245 - accuracy: 0.6893 - val_loss: 1.4892 - val_accuracy: 0.5625 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 27/40
# 206/206 [==============================] - ETA: 0s - loss: 0.9907 - accuracy: 0.6851
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 3.1622775802825264e-05.
#
# Epoch 00027: val_accuracy did not improve from 0.75000
# 206/206 [==============================] - 34s 165ms/step - loss: 0.9907 - accuracy: 0.6851 - val_loss: 1.1349 - val_accuracy: 0.6458 - lr: 1.0000e-04
# Learning rate:  3.1622774e-05
# Epoch 28/40
# 206/206 [==============================] - ETA: 0s - loss: 0.8323 - accuracy: 0.7573
# Epoch 00028: val_accuracy improved from 0.75000 to 0.76042, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 34s 167ms/step - loss: 0.8323 - accuracy: 0.7573 - val_loss: 0.8997 - val_accuracy: 0.7604 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 29/40
# 206/206 [==============================] - ETA: 0s - loss: 0.6990 - accuracy: 0.7931
# Epoch 00029: val_accuracy did not improve from 0.76042
# 206/206 [==============================] - 35s 168ms/step - loss: 0.6990 - accuracy: 0.7931 - val_loss: 0.9203 - val_accuracy: 0.7396 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 30/40
# 206/206 [==============================] - ETA: 0s - loss: 0.6808 - accuracy: 0.7967
# Epoch 00030: val_accuracy did not improve from 0.76042
# 206/206 [==============================] - 34s 165ms/step - loss: 0.6808 - accuracy: 0.7967 - val_loss: 1.1163 - val_accuracy: 0.6562 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 31/40
# 206/206 [==============================] - ETA: 0s - loss: 0.6566 - accuracy: 0.8046
# Epoch 00031: val_accuracy did not improve from 0.76042
# 206/206 [==============================] - 34s 165ms/step - loss: 0.6566 - accuracy: 0.8046 - val_loss: 0.8872 - val_accuracy: 0.7292 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 32/40
# 206/206 [==============================] - ETA: 0s - loss: 0.6484 - accuracy: 0.8046
# Epoch 00032: val_accuracy did not improve from 0.76042
# 206/206 [==============================] - 34s 165ms/step - loss: 0.6484 - accuracy: 0.8046 - val_loss: 1.0125 - val_accuracy: 0.7083 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 33/40
# 206/206 [==============================] - ETA: 0s - loss: 0.5714 - accuracy: 0.8289
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 9.999999259090306e-06.
#
# Epoch 00033: val_accuracy did not improve from 0.76042
# 206/206 [==============================] - 33s 162ms/step - loss: 0.5714 - accuracy: 0.8289 - val_loss: 0.8649 - val_accuracy: 0.6875 - lr: 3.1623e-05
# Learning rate:  9.999999e-06
# Epoch 34/40
# 206/206 [==============================] - ETA: 0s - loss: 0.5666 - accuracy: 0.8325
# Epoch 00034: val_accuracy did not improve from 0.76042
# 206/206 [==============================] - 34s 167ms/step - loss: 0.5666 - accuracy: 0.8325 - val_loss: 0.8188 - val_accuracy: 0.7188 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 35/40
# 206/206 [==============================] - ETA: 0s - loss: 0.5232 - accuracy: 0.8495
# Epoch 00035: val_accuracy did not improve from 0.76042
# 206/206 [==============================] - 33s 162ms/step - loss: 0.5232 - accuracy: 0.8495 - val_loss: 0.8090 - val_accuracy: 0.7396 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 36/40
# 206/206 [==============================] - ETA: 0s - loss: 0.5283 - accuracy: 0.8398
# Epoch 00036: val_accuracy did not improve from 0.76042
# 206/206 [==============================] - 34s 165ms/step - loss: 0.5283 - accuracy: 0.8398 - val_loss: 0.7537 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 37/40
# 206/206 [==============================] - ETA: 0s - loss: 0.5199 - accuracy: 0.8465
# Epoch 00037: val_accuracy improved from 0.76042 to 0.80208, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 35s 168ms/step - loss: 0.5199 - accuracy: 0.8465 - val_loss: 0.7059 - val_accuracy: 0.8021 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 38/40
# 206/206 [==============================] - ETA: 0s - loss: 0.5062 - accuracy: 0.8538
# Epoch 00038: val_accuracy did not improve from 0.80208
# 206/206 [==============================] - 34s 164ms/step - loss: 0.5062 - accuracy: 0.8538 - val_loss: 0.8279 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 39/40
# 206/206 [==============================] - ETA: 0s - loss: 0.4808 - accuracy: 0.8665
# Epoch 00039: val_accuracy did not improve from 0.80208
# 206/206 [==============================] - 34s 167ms/step - loss: 0.4808 - accuracy: 0.8665 - val_loss: 0.7481 - val_accuracy: 0.7604 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 40/40
# 206/206 [==============================] - ETA: 0s - loss: 0.4684 - accuracy: 0.8762
# Epoch 00040: val_accuracy did not improve from 0.80208
# 206/206 [==============================] - 33s 162ms/step - loss: 0.4684 - accuracy: 0.8762 - val_loss: 0.7615 - val_accuracy: 0.7500 - lr: 1.0000e-05
# CPU times: user 29min 14s, sys: 1min 37s, total: 30min 51s
# Wall time: 23min 28s

# %%
plt.rcParams["figure.figsize"] = [20,10]
plt.subplot(2, 1, 1)
plt.title('Training and test accuracy')
plt.plot(params.epoch, params.history['accuracy'], label='Training accuracy')
plt.plot(params.epoch, params.history['val_accuracy'], label='Test accuracy')
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.title('Training and test loss')
plt.plot(params.epoch, params.history['loss'], label='Training loss')
plt.plot(params.epoch, params.history['val_loss'], label='Test loss')
plt.legend()
plt.grid(True)

plt.show()
