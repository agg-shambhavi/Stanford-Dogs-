# %%
# import all libraries here
import os
import pathlib
import xml.etree.ElementTree as ET
from PIL import Image
import multiprocessing as mp
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *
import datetime as dt
from tensorflow.keras import backend as K
from keras.applications.resnet50 import ResNet50

print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.2.0
# 2.3.0-tf

# %%
TEST_SIZE = 0.2
RANDOM_SEED = 28

targetx = 224
targety = 224

batch_size = 8

learning_rate =  0.0001

np.random.seed(RANDOM_SEED)

# %%
ANNOTATION_DIR = pathlib.Path('../input/stanford-dogs-dataset/annotations/Annotation')
IMAGES_DIR = pathlib.Path('../input/stanford-dogs-dataset/images/Images')

BREED_DIR = [path for path in IMAGES_DIR.iterdir()]
BREED_DIR_NAME = [path.name for path in BREED_DIR]

BREED_CODE_TO_NAME = {breed.split('-')[0]: breed.split('-')[1] for breed in BREED_DIR_NAME}


BREED_CODE_TO_NAME = {breed.split('-')[0]: breed.split('-')[1] for breed in BREED_DIR_NAME}


BREED_NAME_TO_CODE = {v: k for k, v in BREED_CODE_TO_NAME.items()}


BREED_LABEL_TO_CODE = {i: code for i, code in enumerate(BREED_CODE_TO_NAME)}


BREED_CODE_TO_LABEL = {v: k for k, v in BREED_LABEL_TO_CODE.items()}


BREED_LABEL_TO_NAME = {i: BREED_CODE_TO_NAME[code] for i, code in BREED_LABEL_TO_CODE.items()}


BREED_NAME_TO_LABEL = {v: k for k, v in BREED_LABEL_TO_NAME.items()}

# %%
def path_to_label(path):
    code = path.stem.split('_')[0]
    return BREED_CODE_TO_LABEL[code]

def get_all_file_path(directory, file_pattern=''):
    paths = list(f for f in directory.rglob('**/*{}'.format(file_pattern)) if f.is_file())
    return sorted(paths, key=str)

# %%
all_image_paths = get_all_file_path(IMAGES_DIR, '.jpg') # PosixPath

all_image_labels = [path_to_label(path) for path in all_image_paths]

assert len(all_image_paths)==len(all_image_labels), 'Numbers of images and labels not match! {}!={}'.format(len(all_image_paths), len(all_image_labels))

# %%
with open('labels.txt', 'w') as f:
    f.write('\n'.join(BREED_NAME_TO_LABEL))# Write labels to file

# %%
# Crop and save images according to boundings

# making a directory to save cropped images
IMAGES_CROPPED_DIR = pathlib.Path('/kaggle/working/images_cropped/')
IMAGES_CROPPED_DIR.mkdir(parents=True, exist_ok=True) 
print('done')
# Out:
# done

# %%
# Gets object boundings
def parse_bounding(path):
    # Get annotation path from image path
    path = ANNOTATION_DIR / path.parent.name / path.stem
    
    # Parse boundings
    tree = ET.parse(path)
    bndbox = tree.getroot().findall('object')[0].find('bndbox')
    left = int(bndbox.find('xmin').text)
    right = int(bndbox.find('xmax').text) 
    upper = int(bndbox.find('ymin').text)
    lower = int(bndbox.find('ymax').text) 
    
    return (left, upper, right, lower)

# %%
def crop_and_save_image(path, save_dir=IMAGES_CROPPED_DIR):
    box = parse_bounding(path)
    
    image = Image.open(path)
    image_cropped = image.crop(box)
    image_cropped = image_cropped.convert('RGB')
    image_cropped.save(save_dir / path.name)

# %%
# %%time
try:
    pool = mp.Pool(processes=mp.cpu_count())
    pool.map(crop_and_save_image, all_image_paths)
except Exception as e:
    print(e)
finally:
    pool.close()
# Out:
# CPU times: user 215 ms, sys: 69.5 ms, total: 284 ms
# Wall time: 4min 3s

# %%
all_image_cropped_paths = get_all_file_path(IMAGES_CROPPED_DIR, '.jpg') # PosixPath
all_image_cropped_labels = [path_to_label(path) for path in all_image_cropped_paths] # [0,1,2,...]

assert len(all_image_paths)==len(all_image_cropped_paths), 'Numbers of images and cropped images not match! {}!={}'.format(len(all_image_paths), len(all_image_cropped_paths))

# %%
IMAGE_PATH = all_image_cropped_paths
LABEL = all_image_cropped_labels

# %%
# Label distribution
_ = plt.hist(LABEL, bins=120)
plt.xlabel('Label index')
plt.ylabel('Count')
plt.title('Label Distribution')
plt.show()

# %%
# Ramdomly check a dog image from the dataset
dog = np.random.choice(IMAGE_PATH)
print('Random dog: ', BREED_LABEL_TO_NAME[path_to_label(dog)])
Image.open(dog)
# Out:
# Random dog:  West_Highland_white_terrier
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=173x197 at 0x7F3A70237FD0>

# %%
# splitting into training and test set
x_train, x_test, y_train, y_test = train_test_split(IMAGE_PATH, 
                                                    LABEL,
                                                    test_size=TEST_SIZE, 
                                                    random_state=RANDOM_SEED,
                                                    shuffle=True,
                                                    stratify=LABEL)

print('Train data: ', len(x_train))
print('Test data: ', len(x_test))
# Out:
# Train data:  16464
# Test data:  4116

# %%
classes = BREED_NAME_TO_CODE.keys()
TRAIN_DIR = pathlib.Path('/kaggle/working/train_dir/')
TRAIN_DIR.mkdir(parents=True, exist_ok=True)

VALIDATION_DIR = pathlib.Path('/kaggle/working/val_dir/')
VALIDATION_DIR.mkdir(parents=True, exist_ok=True)

# %%
# %%time
def make_classes_folder(folder_path):
    for c in classes:
        path = folder_path / c
        path.mkdir()
        
make_classes_folder(TRAIN_DIR)
make_classes_folder(VALIDATION_DIR)
# Out:
# CPU times: user 2.92 ms, sys: 6.93 ms, total: 9.85 ms
# Wall time: 9.77 ms

# %%
# %%time
def copy_img_to_folder(path_array,folder_path):
    for img_path in path_array:
        code_to_label = BREED_CODE_TO_NAME.get(img_path.stem.split('_')[0])
        image = Image.open(img_path)
        image.save(folder_path / code_to_label / img_path.name)


copy_img_to_folder(x_train,TRAIN_DIR)

copy_img_to_folder(x_test,VALIDATION_DIR)
# Out:
# CPU times: user 3min 24s, sys: 2.11 s, total: 3min 26s
# Wall time: 3min 28s

# %%
datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        fill_mode = 'nearest',
        validation_split=TEST_SIZE
        #preprocessing_function=preprocess_input
)

train_generator = datagen.flow_from_directory(
        TRAIN_DIR,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=RANDOM_SEED,
        subset="training"
)


test_generator = datagen.flow_from_directory(
        VALIDATION_DIR,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=RANDOM_SEED,
        subset="validation"
)
# Out:
# Found 13210 images belonging to 120 classes.
# Found 784 images belonging to 120 classes.

# %%
checkpoint = ModelCheckpoint('dog_breed_classifier.h5',
                             monitor='val_accuracy',
                             save_best_only=True,
                             verbose=1,
                             mode='auto',
                             save_weights_only=False,
                             period=1)

tensorboard = TensorBoard(log_dir="./logs-"+dt.datetime.now().strftime("%m%d%Y%H%M%S"),
                            histogram_freq=0,
                            batch_size=batch_size,
                            write_graph=False,
                            update_freq='epoch')

def epoch_end(epoch, logs):
    message = "End of epoch "+str(epoch)+". Learning rate: "+str(K.eval(model.optimizer.lr))
    os.system('echo '+message)

def epoch_begin(epoch, logs):
    print("Learning rate: ", K.eval(model.optimizer.lr))
    
def train_begin(logs):
    os.system("echo Beginning training")

earlystop = EarlyStopping(monitor='val_accuracy',
                          min_delta=.0001,
                          patience=20,
                          verbose=1,
                          mode='auto',
                          baseline=None,
                          restore_best_weights=True)

reducelr = ReduceLROnPlateau(monitor='val_accuracy',
                             factor=np.sqrt(.1),
                             patience=5,
                             verbose=1,
                             mode='auto',
                             min_delta=.0001,
                             cooldown=0,
                             min_lr=0.0000001)

lambdacb = LambdaCallback(on_epoch_begin=epoch_begin,
                          on_epoch_end=epoch_end,
                          on_batch_begin=None,
                          on_batch_end=None,
                          on_train_begin=train_begin,
                          on_train_end=None)

# %%
# %%time
base_model = ResNet50(include_top=False, weights='imagenet', input_shape=(targetx,targety,3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
predictions = Dense(len(classes), activation='softmax', kernel_initializer='random_uniform', bias_initializer='zeros')(x)
model = Model(inputs=base_model.input, outputs=predictions)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# CPU times: user 3.89 s, sys: 927 ms, total: 4.82 s
# Wall time: 6.74 s

# %%
# %%time
optimizer = Adam(lr=learning_rate)
loss = "categorical_crossentropy"
e = 40

for layer in model.layers:
    layer.trainable = True
    
model.compile(optimizer=optimizer,
              loss=loss,
              metrics=["accuracy"])

#model.summary()

params = model.fit_generator(generator=train_generator, 
                                steps_per_epoch=len(train_generator)//batch_size, 
                                validation_data=test_generator, 
                                validation_steps=len(test_generator)//batch_size,
                                epochs=e,
                                callbacks=[reducelr,earlystop, lambdacb, tensorboard, checkpoint])
# Out:
# Learning rate:  1e-04
# Epoch 1/40
# 206/206 [==============================] - ETA: 0s - loss: 3.9665 - accuracy: 0.1535
# Epoch 00001: val_accuracy improved from -inf to 0.38542, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 38s 187ms/step - loss: 3.9665 - accuracy: 0.1535 - val_loss: 2.5888 - val_accuracy: 0.3854 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 2/40
# 206/206 [==============================] - ETA: 0s - loss: 2.5141 - accuracy: 0.3647
# Epoch 00002: val_accuracy improved from 0.38542 to 0.42708, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 37s 179ms/step - loss: 2.5141 - accuracy: 0.3647 - val_loss: 2.1886 - val_accuracy: 0.4271 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 3/40
# 206/206 [==============================] - ETA: 0s - loss: 2.0084 - accuracy: 0.4630
# Epoch 00003: val_accuracy improved from 0.42708 to 0.55208, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 37s 179ms/step - loss: 2.0084 - accuracy: 0.4630 - val_loss: 1.6446 - val_accuracy: 0.5521 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 4/40
# 206/206 [==============================] - ETA: 0s - loss: 1.7440 - accuracy: 0.5303
# Epoch 00004: val_accuracy improved from 0.55208 to 0.57292, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 37s 181ms/step - loss: 1.7440 - accuracy: 0.5303 - val_loss: 1.4955 - val_accuracy: 0.5729 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 5/40
# 206/206 [==============================] - ETA: 0s - loss: 1.5467 - accuracy: 0.5694
# Epoch 00005: val_accuracy improved from 0.57292 to 0.72917, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 37s 180ms/step - loss: 1.5467 - accuracy: 0.5694 - val_loss: 1.1799 - val_accuracy: 0.7292 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 6/40
# 206/206 [==============================] - ETA: 0s - loss: 1.4591 - accuracy: 0.5816
# Epoch 00006: val_accuracy did not improve from 0.72917
# 206/206 [==============================] - 36s 175ms/step - loss: 1.4591 - accuracy: 0.5816 - val_loss: 1.0859 - val_accuracy: 0.6771 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 7/40
# 206/206 [==============================] - ETA: 0s - loss: 1.3194 - accuracy: 0.6329
# Epoch 00007: val_accuracy did not improve from 0.72917
# 206/206 [==============================] - 35s 171ms/step - loss: 1.3194 - accuracy: 0.6329 - val_loss: 1.2514 - val_accuracy: 0.5833 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 8/40
# 206/206 [==============================] - ETA: 0s - loss: 1.2522 - accuracy: 0.6510
# Epoch 00008: val_accuracy did not improve from 0.72917
# 206/206 [==============================] - 36s 174ms/step - loss: 1.2522 - accuracy: 0.6510 - val_loss: 1.6021 - val_accuracy: 0.5625 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 9/40
# 206/206 [==============================] - ETA: 0s - loss: 1.1698 - accuracy: 0.6596
# Epoch 00009: val_accuracy did not improve from 0.72917
# 206/206 [==============================] - 35s 172ms/step - loss: 1.1698 - accuracy: 0.6596 - val_loss: 0.9669 - val_accuracy: 0.7083 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 10/40
# 206/206 [==============================] - ETA: 0s - loss: 1.1071 - accuracy: 0.6833
# Epoch 00010: val_accuracy improved from 0.72917 to 0.79167, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 37s 177ms/step - loss: 1.1071 - accuracy: 0.6833 - val_loss: 0.9939 - val_accuracy: 0.7917 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 11/40
# 206/206 [==============================] - ETA: 0s - loss: 1.0883 - accuracy: 0.6796
# Epoch 00011: val_accuracy did not improve from 0.79167
# 206/206 [==============================] - 36s 175ms/step - loss: 1.0883 - accuracy: 0.6796 - val_loss: 0.7541 - val_accuracy: 0.7292 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 12/40
# 206/206 [==============================] - ETA: 0s - loss: 0.9983 - accuracy: 0.7069
# Epoch 00012: val_accuracy did not improve from 0.79167
# 206/206 [==============================] - 36s 177ms/step - loss: 0.9983 - accuracy: 0.7069 - val_loss: 1.1572 - val_accuracy: 0.6771 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 13/40
# 206/206 [==============================] - ETA: 0s - loss: 1.0377 - accuracy: 0.7192
# Epoch 00013: val_accuracy did not improve from 0.79167
# 206/206 [==============================] - 36s 173ms/step - loss: 1.0377 - accuracy: 0.7192 - val_loss: 1.0094 - val_accuracy: 0.7083 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 14/40
# 206/206 [==============================] - ETA: 0s - loss: 0.9127 - accuracy: 0.7342
# Epoch 00014: val_accuracy did not improve from 0.79167
# 206/206 [==============================] - 36s 174ms/step - loss: 0.9127 - accuracy: 0.7342 - val_loss: 1.2037 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 15/40
# 206/206 [==============================] - ETA: 0s - loss: 0.8881 - accuracy: 0.7294
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 3.1622775802825264e-05.
#
# Epoch 00015: val_accuracy did not improve from 0.79167
# 206/206 [==============================] - 35s 171ms/step - loss: 0.8881 - accuracy: 0.7294 - val_loss: 1.1795 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Learning rate:  3.1622774e-05
# Epoch 16/40
# 206/206 [==============================] - ETA: 0s - loss: 0.7420 - accuracy: 0.7876
# Epoch 00016: val_accuracy improved from 0.79167 to 0.80208, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 38s 184ms/step - loss: 0.7420 - accuracy: 0.7876 - val_loss: 0.7321 - val_accuracy: 0.8021 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 17/40
# 206/206 [==============================] - ETA: 0s - loss: 0.6361 - accuracy: 0.8107
# Epoch 00017: val_accuracy improved from 0.80208 to 0.81250, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 37s 179ms/step - loss: 0.6361 - accuracy: 0.8107 - val_loss: 0.6820 - val_accuracy: 0.8125 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 18/40
# 206/206 [==============================] - ETA: 0s - loss: 0.6076 - accuracy: 0.8307
# Epoch 00018: val_accuracy did not improve from 0.81250
# 206/206 [==============================] - 34s 165ms/step - loss: 0.6076 - accuracy: 0.8307 - val_loss: 0.6731 - val_accuracy: 0.7917 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 19/40
# 206/206 [==============================] - ETA: 0s - loss: 0.5421 - accuracy: 0.8532
# Epoch 00019: val_accuracy improved from 0.81250 to 0.82292, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 36s 176ms/step - loss: 0.5421 - accuracy: 0.8532 - val_loss: 0.6909 - val_accuracy: 0.8229 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 20/40
# 206/206 [==============================] - ETA: 0s - loss: 0.5280 - accuracy: 0.8525
# Epoch 00020: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 34s 164ms/step - loss: 0.5280 - accuracy: 0.8525 - val_loss: 0.7078 - val_accuracy: 0.8229 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 21/40
# 206/206 [==============================] - ETA: 0s - loss: 0.5316 - accuracy: 0.8477
# Epoch 00021: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 35s 168ms/step - loss: 0.5316 - accuracy: 0.8477 - val_loss: 0.6845 - val_accuracy: 0.7917 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 22/40
# 206/206 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.8738
# Epoch 00022: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 34s 164ms/step - loss: 0.4636 - accuracy: 0.8738 - val_loss: 0.7076 - val_accuracy: 0.7812 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 23/40
# 206/206 [==============================] - ETA: 0s - loss: 0.4878 - accuracy: 0.8647
# Epoch 00023: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 33s 163ms/step - loss: 0.4878 - accuracy: 0.8647 - val_loss: 0.7137 - val_accuracy: 0.7604 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 24/40
# 206/206 [==============================] - ETA: 0s - loss: 0.4821 - accuracy: 0.8556
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 9.999999259090306e-06.
#
# Epoch 00024: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 33s 163ms/step - loss: 0.4821 - accuracy: 0.8556 - val_loss: 0.5837 - val_accuracy: 0.8021 - lr: 3.1623e-05
# Learning rate:  9.999999e-06
# Epoch 25/40
# 206/206 [==============================] - ETA: 0s - loss: 0.4018 - accuracy: 0.8908
# Epoch 00025: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 33s 162ms/step - loss: 0.4018 - accuracy: 0.8908 - val_loss: 0.6585 - val_accuracy: 0.8021 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 26/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3779 - accuracy: 0.8993
# Epoch 00026: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 34s 166ms/step - loss: 0.3779 - accuracy: 0.8993 - val_loss: 0.6410 - val_accuracy: 0.8021 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 27/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3804 - accuracy: 0.8940
# Epoch 00027: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 33s 160ms/step - loss: 0.3804 - accuracy: 0.8940 - val_loss: 0.6878 - val_accuracy: 0.8021 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 28/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3751 - accuracy: 0.8952
# Epoch 00028: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 34s 167ms/step - loss: 0.3751 - accuracy: 0.8952 - val_loss: 0.6543 - val_accuracy: 0.8021 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 29/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3372 - accuracy: 0.9129
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 3.162277292675049e-06.
#
# Epoch 00029: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 33s 160ms/step - loss: 0.3372 - accuracy: 0.9129 - val_loss: 0.6463 - val_accuracy: 0.7812 - lr: 1.0000e-05
# Learning rate:  3.1622774e-06
# Epoch 30/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3344 - accuracy: 0.9160
# Epoch 00030: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 34s 165ms/step - loss: 0.3344 - accuracy: 0.9160 - val_loss: 0.6027 - val_accuracy: 0.7917 - lr: 3.1623e-06
# Learning rate:  3.1622774e-06
# Epoch 31/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3131 - accuracy: 0.9138
# Epoch 00031: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 34s 164ms/step - loss: 0.3131 - accuracy: 0.9138 - val_loss: 0.6074 - val_accuracy: 0.7917 - lr: 3.1623e-06
# Learning rate:  3.1622774e-06
# Epoch 32/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3109 - accuracy: 0.9275
# Epoch 00032: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 33s 161ms/step - loss: 0.3109 - accuracy: 0.9275 - val_loss: 0.5855 - val_accuracy: 0.8125 - lr: 3.1623e-06
# Learning rate:  3.1622774e-06
# Epoch 33/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3215 - accuracy: 0.9157
# Epoch 00033: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 33s 162ms/step - loss: 0.3215 - accuracy: 0.9157 - val_loss: 0.5784 - val_accuracy: 0.8125 - lr: 3.1623e-06
# Learning rate:  3.1622774e-06
# Epoch 34/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3214 - accuracy: 0.9072
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 9.999999115286567e-07.
#
# Epoch 00034: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 33s 160ms/step - loss: 0.3214 - accuracy: 0.9072 - val_loss: 0.6327 - val_accuracy: 0.8125 - lr: 3.1623e-06
# Learning rate:  9.999999e-07
# Epoch 35/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3006 - accuracy: 0.9284
# Epoch 00035: val_accuracy did not improve from 0.82292
# 206/206 [==============================] - 34s 163ms/step - loss: 0.3006 - accuracy: 0.9284 - val_loss: 0.6135 - val_accuracy: 0.8021 - lr: 1.0000e-06
# Learning rate:  9.999999e-07
# Epoch 36/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3244 - accuracy: 0.9126
# Epoch 00036: val_accuracy improved from 0.82292 to 0.84375, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 34s 167ms/step - loss: 0.3244 - accuracy: 0.9126 - val_loss: 0.6097 - val_accuracy: 0.8438 - lr: 1.0000e-06
# Learning rate:  9.999999e-07
# Epoch 37/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2906 - accuracy: 0.9314
# Epoch 00037: val_accuracy improved from 0.84375 to 0.87500, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 35s 169ms/step - loss: 0.2906 - accuracy: 0.9314 - val_loss: 0.5523 - val_accuracy: 0.8750 - lr: 1.0000e-06
# Learning rate:  9.999999e-07
# Epoch 38/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.9229
# Epoch 00038: val_accuracy did not improve from 0.87500
# 206/206 [==============================] - 34s 163ms/step - loss: 0.3019 - accuracy: 0.9229 - val_loss: 0.5888 - val_accuracy: 0.7812 - lr: 1.0000e-06
# Learning rate:  9.999999e-07
# Epoch 39/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3216 - accuracy: 0.9175
# Epoch 00039: val_accuracy did not improve from 0.87500
# 206/206 [==============================] - 33s 161ms/step - loss: 0.3216 - accuracy: 0.9175 - val_loss: 0.5970 - val_accuracy: 0.8438 - lr: 1.0000e-06
# Learning rate:  9.999999e-07
# Epoch 40/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.9306
# Epoch 00040: val_accuracy did not improve from 0.87500
# 206/206 [==============================] - 33s 162ms/step - loss: 0.2867 - accuracy: 0.9306 - val_loss: 0.5963 - val_accuracy: 0.8438 - lr: 1.0000e-06
# CPU times: user 29min 26s, sys: 1min 38s, total: 31min 4s
# Wall time: 23min 37s

# %%
plt.rcParams["figure.figsize"] = [20,10]
plt.subplot(2, 1, 1)
plt.title('Training and test accuracy')
plt.plot(params.epoch, params.history['accuracy'], label='Training accuracy')
plt.plot(params.epoch, params.history['val_accuracy'], label='Test accuracy')
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.title('Training and test loss')
plt.plot(params.epoch, params.history['loss'], label='Training loss')
plt.plot(params.epoch, params.history['val_loss'], label='Test loss')
plt.legend()
plt.grid(True)

plt.show()
