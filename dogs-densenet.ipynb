# %%
# import all libraries here
import os
import pathlib
import xml.etree.ElementTree as ET
from PIL import Image
import multiprocessing as mp
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *
import datetime as dt
from tensorflow.keras import backend as K
from tensorflow.keras.applications.densenet import DenseNet121,preprocess_input

# %%
TEST_SIZE = 0.2
RANDOM_SEED = 28

targetx = 224
targety = 224

batch_size = 32

learning_rate =  0.0001

np.random.seed(RANDOM_SEED)

# %%
ANNOTATION_DIR = pathlib.Path('../input/stanford-dogs-dataset/annotations/Annotation')
IMAGES_DIR = pathlib.Path('../input/stanford-dogs-dataset/images/Images')

BREED_DIR = [path for path in IMAGES_DIR.iterdir()]
BREED_DIR_NAME = [path.name for path in BREED_DIR]

BREED_CODE_TO_NAME = {breed.split('-')[0]: breed.split('-')[1] for breed in BREED_DIR_NAME}


BREED_CODE_TO_NAME = {breed.split('-')[0]: breed.split('-')[1] for breed in BREED_DIR_NAME}


BREED_NAME_TO_CODE = {v: k for k, v in BREED_CODE_TO_NAME.items()}


BREED_LABEL_TO_CODE = {i: code for i, code in enumerate(BREED_CODE_TO_NAME)}


BREED_CODE_TO_LABEL = {v: k for k, v in BREED_LABEL_TO_CODE.items()}


BREED_LABEL_TO_NAME = {i: BREED_CODE_TO_NAME[code] for i, code in BREED_LABEL_TO_CODE.items()}


BREED_NAME_TO_LABEL = {v: k for k, v in BREED_LABEL_TO_NAME.items()}

# %%
def path_to_label(path):
    code = path.stem.split('_')[0]
    return BREED_CODE_TO_LABEL[code]

def get_all_file_path(directory, file_pattern=''):
    paths = list(f for f in directory.rglob('**/*{}'.format(file_pattern)) if f.is_file())
    return sorted(paths, key=str)

# %%
all_image_paths = get_all_file_path(IMAGES_DIR, '.jpg') # PosixPath

all_image_labels = [path_to_label(path) for path in all_image_paths]

assert len(all_image_paths)==len(all_image_labels), 'Numbers of images and labels not match! {}!={}'.format(len(all_image_paths), len(all_image_labels))

# %%
# %%time
with open('labels.txt', 'w') as f:
    f.write('\n'.join(BREED_NAME_TO_LABEL))# Write labels to file
# Out:
# CPU times: user 1.67 ms, sys: 0 ns, total: 1.67 ms
# Wall time: 2.61 ms

# %%
# Crop and save images according to boundings

# making a directory to save cropped images
IMAGES_CROPPED_DIR = pathlib.Path('/kaggle/working/images_cropped/')
IMAGES_CROPPED_DIR.mkdir(parents=True, exist_ok=True) 
print('done')
# Out:
# done

# %%
# Gets object boundings
def parse_bounding(path):
    # Get annotation path from image path
    path = ANNOTATION_DIR / path.parent.name / path.stem
    
    # Parse boundings
    tree = ET.parse(path)
    bndbox = tree.getroot().findall('object')[0].find('bndbox')
    left = int(bndbox.find('xmin').text)
    right = int(bndbox.find('xmax').text) 
    upper = int(bndbox.find('ymin').text)
    lower = int(bndbox.find('ymax').text) 
    
    return (left, upper, right, lower)

# %%
def crop_and_save_image(path, save_dir=IMAGES_CROPPED_DIR):
    box = parse_bounding(path)
    
    image = Image.open(path)
    image_cropped = image.crop(box)
    image_cropped = image_cropped.convert('RGB')
    image_cropped.save(save_dir / path.name)

# %%
# %%time
try:
    pool = mp.Pool(processes=mp.cpu_count())
    pool.map(crop_and_save_image, all_image_paths)
except Exception as e:
    print(e)
finally:
    pool.close()
# Out:
# CPU times: user 176 ms, sys: 74.1 ms, total: 250 ms
# Wall time: 4min 7s

# %%
all_image_cropped_paths = get_all_file_path(IMAGES_CROPPED_DIR, '.jpg') # PosixPath
all_image_cropped_labels = [path_to_label(path) for path in all_image_cropped_paths] # [0,1,2,...]

# %%
assert len(all_image_paths)==len(all_image_cropped_paths), 'Numbers of images and cropped images not match! {}!={}'.format(len(all_image_paths), len(all_image_cropped_paths))

# %%
IMAGE_PATH = all_image_cropped_paths
LABEL = all_image_cropped_labels

# %%
x_train, x_test, y_train, y_test = train_test_split(IMAGE_PATH, 
                                                    LABEL,
                                                    test_size=TEST_SIZE, 
                                                    random_state=RANDOM_SEED,
                                                    shuffle=True,
                                                    stratify=LABEL)

print('Train data: ', len(x_train))
print('Test data: ', len(x_test))
# Out:
# Train data:  16464
# Test data:  4116

# %%
classes = BREED_NAME_TO_CODE.keys()

TRAIN_DIR = pathlib.Path('/kaggle/working/train_dir/')
TRAIN_DIR.mkdir(parents=True, exist_ok=True)

VALIDATION_DIR = pathlib.Path('/kaggle/working/val_dir/')
VALIDATION_DIR.mkdir(parents=True, exist_ok=True)

# %%
def make_classes_folder(folder_path):
    for c in classes:
        path = folder_path / c
        path.mkdir()
        
make_classes_folder(TRAIN_DIR)
make_classes_folder(VALIDATION_DIR)

# %%
# %%time
def copy_img_to_folder(path_array,folder_path):
    for img_path in path_array:
        code_to_label = BREED_CODE_TO_NAME.get(img_path.stem.split('_')[0])
        image = Image.open(img_path)
        image.save(folder_path / code_to_label / img_path.name)
        
copy_img_to_folder(x_train,TRAIN_DIR)

copy_img_to_folder(x_test,VALIDATION_DIR)
# Out:
# CPU times: user 3min 23s, sys: 2.11 s, total: 3min 25s
# Wall time: 3min 26s

# %%
datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        fill_mode = 'nearest',
        validation_split=TEST_SIZE,
        preprocessing_function=preprocess_input
)

train_generator = datagen.flow_from_directory(
        TRAIN_DIR,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=RANDOM_SEED,
        subset="training"
)


test_generator = datagen.flow_from_directory(
        VALIDATION_DIR,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=RANDOM_SEED,
        subset="validation"
)
# Out:
# Found 13210 images belonging to 120 classes.
# Found 784 images belonging to 120 classes.

# %%
checkpoint = ModelCheckpoint('dog_breed_classifier.h5',
                             monitor='val_accuracy',
                             save_best_only=True,
                             verbose=1,
                             mode='auto',
                             save_weights_only=False,
                             period=1)

tensorboard = TensorBoard(log_dir="./logs-"+dt.datetime.now().strftime("%m%d%Y%H%M%S"),
                            histogram_freq=0,
                            batch_size=batch_size,
                            write_graph=False,
                            update_freq='epoch')

def epoch_end(epoch, logs):
    message = "End of epoch "+str(epoch)+". Learning rate: "+str(K.eval(model.optimizer.lr))
    os.system('echo '+message)

def epoch_begin(epoch, logs):
    print("Learning rate: ", K.eval(model.optimizer.lr))
    
def train_begin(logs):
    os.system("echo Beginning training")

earlystop = EarlyStopping(monitor='val_accuracy',
                          min_delta=.0001,
                          patience=20,
                          verbose=1,
                          mode='auto',
                          baseline=None,
                          restore_best_weights=True)

reducelr = ReduceLROnPlateau(monitor='val_accuracy',
                             factor=np.sqrt(.1),
                             patience=5,
                             verbose=1,
                             mode='auto',
                             min_delta=.0001,
                             cooldown=0,
                             min_lr=0.0000001)

lambdacb = LambdaCallback(on_epoch_begin=epoch_begin,
                          on_epoch_end=epoch_end,
                          on_batch_begin=None,
                          on_batch_end=None,
                          on_train_begin=train_begin,
                          on_train_end=None)

# %%
# %%time
inpt = Input(shape=(targetx,targety,3))
backbone = DenseNet121(input_tensor=inpt,
                       weights="imagenet",
                       include_top=False)
x = backbone.output
x = GlobalAveragePooling2D()(x)
x = Dense(1280, activation='relu',  kernel_initializer=glorot_uniform(RANDOM_SEED), bias_initializer='zeros')(x)
x = BatchNormalization()(x)
outp = Dense(120, activation="softmax",kernel_initializer='random_uniform', bias_initializer='zeros')(x)
model = Model(inpt, outp)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# CPU times: user 6.99 s, sys: 838 ms, total: 7.83 s
# Wall time: 9.94 s

# %%
######
e = 20
######
loss = "categorical_crossentropy"
optimizer = Adam(lr=learning_rate)

for layer in model.layers:
    layer.trainable = True
    
model.compile(optimizer=optimizer,
              loss=loss,
              metrics=["accuracy"])
params = model.fit_generator(generator=train_generator, 
                                steps_per_epoch=len(train_generator)//2, 
                                validation_data=test_generator, 
                                validation_steps=len(test_generator),
                                epochs=e,
                                callbacks=[reducelr,earlystop, lambdacb, tensorboard, checkpoint])
# Out:
# Learning rate:  1e-04
# Epoch 1/20
# 206/206 [==============================] - ETA: 0s - loss: 2.3417 - accuracy: 0.4649
# Epoch 00001: val_accuracy improved from -inf to 0.72577, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 141s 684ms/step - loss: 2.3417 - accuracy: 0.4649 - val_loss: 1.2730 - val_accuracy: 0.7258 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 2/20
# 206/206 [==============================] - ETA: 0s - loss: 0.8727 - accuracy: 0.7592
# Epoch 00002: val_accuracy improved from 0.72577 to 0.76020, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 137s 667ms/step - loss: 0.8727 - accuracy: 0.7592 - val_loss: 0.8963 - val_accuracy: 0.7602 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 3/20
# 206/206 [==============================] - ETA: 0s - loss: 0.6287 - accuracy: 0.8318
# Epoch 00003: val_accuracy improved from 0.76020 to 0.77041, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 136s 659ms/step - loss: 0.6287 - accuracy: 0.8318 - val_loss: 0.8006 - val_accuracy: 0.7704 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 4/20
# 206/206 [==============================] - ETA: 0s - loss: 0.4968 - accuracy: 0.8576
# Epoch 00004: val_accuracy improved from 0.77041 to 0.79464, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 136s 659ms/step - loss: 0.4968 - accuracy: 0.8576 - val_loss: 0.7257 - val_accuracy: 0.7946 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 5/20
# 206/206 [==============================] - ETA: 0s - loss: 0.4066 - accuracy: 0.8845
# Epoch 00005: val_accuracy did not improve from 0.79464
# 206/206 [==============================] - 134s 652ms/step - loss: 0.4066 - accuracy: 0.8845 - val_loss: 0.7170 - val_accuracy: 0.7730 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 6/20
# 206/206 [==============================] - ETA: 0s - loss: 0.3443 - accuracy: 0.9085
# Epoch 00006: val_accuracy did not improve from 0.79464
# 206/206 [==============================] - 134s 651ms/step - loss: 0.3443 - accuracy: 0.9085 - val_loss: 0.7122 - val_accuracy: 0.7883 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 7/20
# 206/206 [==============================] - ETA: 0s - loss: 0.2785 - accuracy: 0.9194
# Epoch 00007: val_accuracy improved from 0.79464 to 0.79974, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 136s 659ms/step - loss: 0.2785 - accuracy: 0.9194 - val_loss: 0.6907 - val_accuracy: 0.7997 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 8/20
# 206/206 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9399
# Epoch 00008: val_accuracy did not improve from 0.79974
# 206/206 [==============================] - 134s 651ms/step - loss: 0.2308 - accuracy: 0.9399 - val_loss: 0.7042 - val_accuracy: 0.7985 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 9/20
# 206/206 [==============================] - ETA: 0s - loss: 0.2034 - accuracy: 0.9467
# Epoch 00009: val_accuracy did not improve from 0.79974
# 206/206 [==============================] - 133s 647ms/step - loss: 0.2034 - accuracy: 0.9467 - val_loss: 0.6809 - val_accuracy: 0.7972 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 10/20
# 206/206 [==============================] - ETA: 0s - loss: 0.1727 - accuracy: 0.9564
# Epoch 00010: val_accuracy improved from 0.79974 to 0.80867, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 136s 662ms/step - loss: 0.1727 - accuracy: 0.9564 - val_loss: 0.6685 - val_accuracy: 0.8087 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 11/20
# 206/206 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9637
# Epoch 00011: val_accuracy did not improve from 0.80867
# 206/206 [==============================] - 134s 651ms/step - loss: 0.1495 - accuracy: 0.9637 - val_loss: 0.7062 - val_accuracy: 0.8036 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 12/20
# 206/206 [==============================] - ETA: 0s - loss: 0.1308 - accuracy: 0.9654
# Epoch 00012: val_accuracy did not improve from 0.80867
# 206/206 [==============================] - 135s 654ms/step - loss: 0.1308 - accuracy: 0.9654 - val_loss: 0.7115 - val_accuracy: 0.7985 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 13/20
# 206/206 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.9701
# Epoch 00013: val_accuracy improved from 0.80867 to 0.81505, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 140s 678ms/step - loss: 0.1213 - accuracy: 0.9701 - val_loss: 0.6930 - val_accuracy: 0.8151 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 14/20
# 206/206 [==============================] - ETA: 0s - loss: 0.1118 - accuracy: 0.9739
# Epoch 00014: val_accuracy did not improve from 0.81505
# 206/206 [==============================] - 143s 692ms/step - loss: 0.1118 - accuracy: 0.9739 - val_loss: 0.7566 - val_accuracy: 0.7959 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 15/20
# 206/206 [==============================] - ETA: 0s - loss: 0.0888 - accuracy: 0.9798
# Epoch 00015: val_accuracy improved from 0.81505 to 0.81760, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 147s 714ms/step - loss: 0.0888 - accuracy: 0.9798 - val_loss: 0.7554 - val_accuracy: 0.8176 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 16/20
# 206/206 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9781
# Epoch 00016: val_accuracy did not improve from 0.81760
# 206/206 [==============================] - 148s 719ms/step - loss: 0.0989 - accuracy: 0.9781 - val_loss: 0.8568 - val_accuracy: 0.7819 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 17/20
# 206/206 [==============================] - ETA: 0s - loss: 0.0897 - accuracy: 0.9792
# Epoch 00017: val_accuracy did not improve from 0.81760
# 206/206 [==============================] - 147s 716ms/step - loss: 0.0897 - accuracy: 0.9792 - val_loss: 0.7948 - val_accuracy: 0.7908 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 18/20
# 206/206 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9818
# Epoch 00018: val_accuracy did not improve from 0.81760
# 206/206 [==============================] - 149s 725ms/step - loss: 0.0745 - accuracy: 0.9818 - val_loss: 0.8528 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 19/20
# 206/206 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9788
# Epoch 00019: val_accuracy did not improve from 0.81760
# 206/206 [==============================] - 149s 725ms/step - loss: 0.0734 - accuracy: 0.9788 - val_loss: 0.8469 - val_accuracy: 0.7755 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 20/20
# 206/206 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9816
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.1622775802825264e-05.
#
# Epoch 00020: val_accuracy did not improve from 0.81760
# 206/206 [==============================] - 152s 738ms/step - loss: 0.0725 - accuracy: 0.9816 - val_loss: 0.8548 - val_accuracy: 0.7844 - lr: 1.0000e-04

# %%
plt.rcParams["figure.figsize"] = [20,10]
plt.subplot(2, 1, 1)
plt.title('Training and test accuracy')
plt.plot(params.epoch, params.history['accuracy'], label='Training accuracy')
plt.plot(params.epoch, params.history['val_accuracy'], label='Test accuracy')
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.title('Training and test loss')
plt.plot(params.epoch, params.history['loss'], label='Training loss')
plt.plot(params.epoch, params.history['val_loss'], label='Test loss')
plt.legend()
plt.grid(True)

plt.show()
