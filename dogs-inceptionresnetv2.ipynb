# %%
# import all libraries here
import os
import pathlib
import xml.etree.ElementTree as ET
from PIL import Image
import multiprocessing as mp
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *
import datetime as dt
from tensorflow.keras import backend as K
from tensorflow.keras.applications import InceptionResNetV2

print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.2.0
# 2.3.0-tf

# %%
TEST_SIZE = 0.2
RANDOM_SEED = 28

targetx = 224
targety = 224

batch_size = 8

learning_rate =  0.0001

np.random.seed(RANDOM_SEED)

# %%
ANNOTATION_DIR = pathlib.Path('../input/stanford-dogs-dataset/annotations/Annotation')
IMAGES_DIR = pathlib.Path('../input/stanford-dogs-dataset/images/Images')

BREED_DIR = [path for path in IMAGES_DIR.iterdir()]
BREED_DIR_NAME = [path.name for path in BREED_DIR]

BREED_CODE_TO_NAME = {breed.split('-')[0]: breed.split('-')[1] for breed in BREED_DIR_NAME}


BREED_CODE_TO_NAME = {breed.split('-')[0]: breed.split('-')[1] for breed in BREED_DIR_NAME}


BREED_NAME_TO_CODE = {v: k for k, v in BREED_CODE_TO_NAME.items()}


BREED_LABEL_TO_CODE = {i: code for i, code in enumerate(BREED_CODE_TO_NAME)}


BREED_CODE_TO_LABEL = {v: k for k, v in BREED_LABEL_TO_CODE.items()}


BREED_LABEL_TO_NAME = {i: BREED_CODE_TO_NAME[code] for i, code in BREED_LABEL_TO_CODE.items()}


BREED_NAME_TO_LABEL = {v: k for k, v in BREED_LABEL_TO_NAME.items()}

# %%
def path_to_label(path):
    code = path.stem.split('_')[0]
    return BREED_CODE_TO_LABEL[code]

def get_all_file_path(directory, file_pattern=''):
    paths = list(f for f in directory.rglob('**/*{}'.format(file_pattern)) if f.is_file())
    return sorted(paths, key=str)

# %%
all_image_paths = get_all_file_path(IMAGES_DIR, '.jpg') # PosixPath

all_image_labels = [path_to_label(path) for path in all_image_paths]

assert len(all_image_paths)==len(all_image_labels), 'Numbers of images and labels not match! {}!={}'.format(len(all_image_paths), len(all_image_labels))

# %%
with open('labels.txt', 'w') as f:
    f.write('\n'.join(BREED_NAME_TO_LABEL))# Write labels to file

# %%
# Crop and save images according to boundings

# making a directory to save cropped images
IMAGES_CROPPED_DIR = pathlib.Path('/kaggle/working/images_cropped/')
IMAGES_CROPPED_DIR.mkdir(parents=True, exist_ok=True) 
print('done')
# Out:
# done

# %%
# Gets object boundings
def parse_bounding(path):
    # Get annotation path from image path
    path = ANNOTATION_DIR / path.parent.name / path.stem
    
    # Parse boundings
    tree = ET.parse(path)
    bndbox = tree.getroot().findall('object')[0].find('bndbox')
    left = int(bndbox.find('xmin').text)
    right = int(bndbox.find('xmax').text) 
    upper = int(bndbox.find('ymin').text)
    lower = int(bndbox.find('ymax').text) 
    
    return (left, upper, right, lower)

# %%
def crop_and_save_image(path, save_dir=IMAGES_CROPPED_DIR):
    box = parse_bounding(path)
    
    image = Image.open(path)
    image_cropped = image.crop(box)
    image_cropped = image_cropped.convert('RGB')
    image_cropped.save(save_dir / path.name)

# %%
# %%time
try:
    pool = mp.Pool(processes=mp.cpu_count())
    pool.map(crop_and_save_image, all_image_paths)
except Exception as e:
    print(e)
finally:
    pool.close()
# Out:
# CPU times: user 160 ms, sys: 58 ms, total: 218 ms
# Wall time: 3min 53s

# %%
all_image_cropped_paths = get_all_file_path(IMAGES_CROPPED_DIR, '.jpg') # PosixPath
all_image_cropped_labels = [path_to_label(path) for path in all_image_cropped_paths] # [0,1,2,...]

assert len(all_image_paths)==len(all_image_cropped_paths), 'Numbers of images and cropped images not match! {}!={}'.format(len(all_image_paths), len(all_image_cropped_paths))

# %%
IMAGE_PATH = all_image_cropped_paths
LABEL = all_image_cropped_labels

# %%
# Label distribution
_ = plt.hist(LABEL, bins=120)
plt.xlabel('Label index')
plt.ylabel('Count')
plt.title('Label Distribution')
plt.show()

# %%
# Ramdomly check a dog image from the dataset
dog = np.random.choice(IMAGE_PATH)
print('Random dog: ', BREED_LABEL_TO_NAME[path_to_label(dog)])
Image.open(dog)
# Out:
# Random dog:  West_Highland_white_terrier
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=173x197 at 0x7F498B6F2550>

# %%
# splitting into training and test set
x_train, x_test, y_train, y_test = train_test_split(IMAGE_PATH, 
                                                    LABEL,
                                                    test_size=TEST_SIZE, 
                                                    random_state=RANDOM_SEED,
                                                    shuffle=True,
                                                    stratify=LABEL)

print('Train data: ', len(x_train))
print('Test data: ', len(x_test))
# Out:
# Train data:  16464
# Test data:  4116

# %%
classes = BREED_NAME_TO_CODE.keys()
TRAIN_DIR = pathlib.Path('/kaggle/working/train_dir/')
TRAIN_DIR.mkdir(parents=True, exist_ok=True)

VALIDATION_DIR = pathlib.Path('/kaggle/working/val_dir/')
VALIDATION_DIR.mkdir(parents=True, exist_ok=True)

# %%
# %%time
def make_classes_folder(folder_path):
    for c in classes:
        path = folder_path / c
        path.mkdir()
        
make_classes_folder(TRAIN_DIR)
make_classes_folder(VALIDATION_DIR)
# Out:
# CPU times: user 2.95 ms, sys: 7.22 ms, total: 10.2 ms
# Wall time: 9.76 ms

# %%
# %%time
def copy_img_to_folder(path_array,folder_path):
    for img_path in path_array:
        code_to_label = BREED_CODE_TO_NAME.get(img_path.stem.split('_')[0])
        image = Image.open(img_path)
        image.save(folder_path / code_to_label / img_path.name)


copy_img_to_folder(x_train,TRAIN_DIR)

copy_img_to_folder(x_test,VALIDATION_DIR)
# Out:
# CPU times: user 3min 22s, sys: 2.14 s, total: 3min 24s
# Wall time: 3min 25s

# %%
datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        fill_mode = 'nearest',
        validation_split=TEST_SIZE
        #preprocessing_function=preprocess_input
)

train_generator = datagen.flow_from_directory(
        TRAIN_DIR,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=RANDOM_SEED,
        subset="training"
)


test_generator = datagen.flow_from_directory(
        VALIDATION_DIR,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=RANDOM_SEED,
        subset="validation"
)
# Out:
# Found 13210 images belonging to 120 classes.
# Found 786 images belonging to 120 classes.

# %%
checkpoint = ModelCheckpoint('dog_breed_classifier.h5',
                             monitor='val_accuracy',
                             save_best_only=True,
                             verbose=1,
                             mode='auto',
                             save_weights_only=False,
                             period=1)

tensorboard = TensorBoard(log_dir="./logs-"+dt.datetime.now().strftime("%m%d%Y%H%M%S"),
                            histogram_freq=0,
                            batch_size=batch_size,
                            write_graph=False,
                            update_freq='epoch')

def epoch_end(epoch, logs):
    message = "End of epoch "+str(epoch)+". Learning rate: "+str(K.eval(model.optimizer.lr))
    os.system('echo '+message)

def epoch_begin(epoch, logs):
    print("Learning rate: ", K.eval(model.optimizer.lr))
    
def train_begin(logs):
    os.system("echo Beginning training")

earlystop = EarlyStopping(monitor='val_accuracy',
                          min_delta=.0001,
                          patience=20,
                          verbose=1,
                          mode='auto',
                          baseline=None,
                          restore_best_weights=True)

reducelr = ReduceLROnPlateau(monitor='val_accuracy',
                             factor=np.sqrt(.1),
                             patience=5,
                             verbose=1,
                             mode='auto',
                             min_delta=.0001,
                             cooldown=0,
                             min_lr=0.0000001)

lambdacb = LambdaCallback(on_epoch_begin=epoch_begin,
                          on_epoch_end=epoch_end,
                          on_batch_begin=None,
                          on_batch_end=None,
                          on_train_begin=train_begin,
                          on_train_end=None)

# %%
# %%time
base_model = InceptionResNetV2(include_top=False, weights='imagenet', input_shape=(targetx,targety,3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
predictions = Dense(len(classes), activation='softmax', kernel_initializer='random_uniform', bias_initializer='zeros')(x)
model = Model(inputs=base_model.input, outputs=predictions)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 1s 0us/step
# CPU times: user 11.7 s, sys: 1.42 s, total: 13.1 s
# Wall time: 15.4 s

# %%
# %%time
optimizer = Adam(lr=learning_rate)
loss = "categorical_crossentropy"
e = 40

for layer in model.layers:
    layer.trainable = True
    
model.compile(optimizer=optimizer,
              loss=loss,
              metrics=["accuracy"])

#model.summary()

params = model.fit_generator(generator=train_generator, 
                                steps_per_epoch=len(train_generator)//batch_size, 
                                validation_data=test_generator, 
                                validation_steps=len(test_generator)//batch_size,
                                epochs=e,
                                callbacks=[reducelr,earlystop, lambdacb, tensorboard, checkpoint])
# Out:
# Learning rate:  1e-04
# Epoch 1/40
# 206/206 [==============================] - ETA: 0s - loss: 3.3886 - accuracy: 0.3004
# Epoch 00001: val_accuracy improved from -inf to 0.57292, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 48s 234ms/step - loss: 3.3886 - accuracy: 0.3004 - val_loss: 2.0314 - val_accuracy: 0.5729 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 2/40
# 206/206 [==============================] - ETA: 0s - loss: 1.9251 - accuracy: 0.5256
# Epoch 00002: val_accuracy did not improve from 0.57292
# 206/206 [==============================] - 42s 202ms/step - loss: 1.9251 - accuracy: 0.5256 - val_loss: 7.5262 - val_accuracy: 0.5417 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 3/40
# 206/206 [==============================] - ETA: 0s - loss: 1.5160 - accuracy: 0.5977
# Epoch 00003: val_accuracy did not improve from 0.57292
# 206/206 [==============================] - 41s 198ms/step - loss: 1.5160 - accuracy: 0.5977 - val_loss: 4.1038 - val_accuracy: 0.5104 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 4/40
# 206/206 [==============================] - ETA: 0s - loss: 1.3295 - accuracy: 0.6390
# Epoch 00004: val_accuracy improved from 0.57292 to 0.71875, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 45s 217ms/step - loss: 1.3295 - accuracy: 0.6390 - val_loss: 1.7448 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 5/40
# 206/206 [==============================] - ETA: 0s - loss: 1.2350 - accuracy: 0.6657
# Epoch 00005: val_accuracy did not improve from 0.71875
# 206/206 [==============================] - 41s 201ms/step - loss: 1.2350 - accuracy: 0.6657 - val_loss: 5.1550 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 6/40
# 206/206 [==============================] - ETA: 0s - loss: 1.1637 - accuracy: 0.6687
# Epoch 00006: val_accuracy did not improve from 0.71875
# 206/206 [==============================] - 41s 199ms/step - loss: 1.1637 - accuracy: 0.6687 - val_loss: 5.7078 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 7/40
# 206/206 [==============================] - ETA: 0s - loss: 1.0082 - accuracy: 0.7282
# Epoch 00007: val_accuracy improved from 0.71875 to 0.78125, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 45s 219ms/step - loss: 1.0082 - accuracy: 0.7282 - val_loss: 1.2260 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 8/40
# 206/206 [==============================] - ETA: 0s - loss: 1.0124 - accuracy: 0.7300
# Epoch 00008: val_accuracy did not improve from 0.78125
# 206/206 [==============================] - 43s 207ms/step - loss: 1.0124 - accuracy: 0.7300 - val_loss: 4.9044 - val_accuracy: 0.6979 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 9/40
# 206/206 [==============================] - ETA: 0s - loss: 0.9600 - accuracy: 0.7217
# Epoch 00009: val_accuracy did not improve from 0.78125
# 206/206 [==============================] - 41s 201ms/step - loss: 0.9600 - accuracy: 0.7217 - val_loss: 8.2039 - val_accuracy: 0.7083 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 10/40
# 206/206 [==============================] - ETA: 0s - loss: 0.8767 - accuracy: 0.7609
# Epoch 00010: val_accuracy did not improve from 0.78125
# 206/206 [==============================] - 42s 202ms/step - loss: 0.8767 - accuracy: 0.7609 - val_loss: 2.2467 - val_accuracy: 0.7188 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 11/40
# 206/206 [==============================] - ETA: 0s - loss: 0.8293 - accuracy: 0.7640
# Epoch 00011: val_accuracy did not improve from 0.78125
# 206/206 [==============================] - 43s 207ms/step - loss: 0.8293 - accuracy: 0.7640 - val_loss: 5.0349 - val_accuracy: 0.7604 - lr: 1.0000e-04
# Learning rate:  1e-04
# Epoch 12/40
# 206/206 [==============================] - ETA: 0s - loss: 0.8488 - accuracy: 0.7555
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 3.1622775802825264e-05.
#
# Epoch 00012: val_accuracy did not improve from 0.78125
# 206/206 [==============================] - 43s 208ms/step - loss: 0.8488 - accuracy: 0.7555 - val_loss: 10.4653 - val_accuracy: 0.7292 - lr: 1.0000e-04
# Learning rate:  3.1622774e-05
# Epoch 13/40
# 206/206 [==============================] - ETA: 0s - loss: 0.7152 - accuracy: 0.8083
# Epoch 00013: val_accuracy improved from 0.78125 to 0.85417, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 45s 221ms/step - loss: 0.7152 - accuracy: 0.8083 - val_loss: 1.7175 - val_accuracy: 0.8542 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 14/40
# 206/206 [==============================] - ETA: 0s - loss: 0.5308 - accuracy: 0.8501
# Epoch 00014: val_accuracy did not improve from 0.85417
# 206/206 [==============================] - 44s 214ms/step - loss: 0.5308 - accuracy: 0.8501 - val_loss: 1.2073 - val_accuracy: 0.8021 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 15/40
# 206/206 [==============================] - ETA: 0s - loss: 0.4891 - accuracy: 0.8574
# Epoch 00015: val_accuracy did not improve from 0.85417
# 206/206 [==============================] - 43s 210ms/step - loss: 0.4891 - accuracy: 0.8574 - val_loss: 4.1478 - val_accuracy: 0.7396 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 16/40
# 206/206 [==============================] - ETA: 0s - loss: 0.4737 - accuracy: 0.8623
# Epoch 00016: val_accuracy did not improve from 0.85417
# 206/206 [==============================] - 43s 208ms/step - loss: 0.4737 - accuracy: 0.8623 - val_loss: 2.2279 - val_accuracy: 0.8229 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 17/40
# 206/206 [==============================] - ETA: 0s - loss: 0.4851 - accuracy: 0.8647
# Epoch 00017: val_accuracy did not improve from 0.85417
# 206/206 [==============================] - 42s 202ms/step - loss: 0.4851 - accuracy: 0.8647 - val_loss: 3.8600 - val_accuracy: 0.7604 - lr: 3.1623e-05
# Learning rate:  3.1622774e-05
# Epoch 18/40
# 206/206 [==============================] - ETA: 0s - loss: 0.4128 - accuracy: 0.8780
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 9.999999259090306e-06.
#
# Epoch 00018: val_accuracy did not improve from 0.85417
# 206/206 [==============================] - 42s 202ms/step - loss: 0.4128 - accuracy: 0.8780 - val_loss: 2.5453 - val_accuracy: 0.8021 - lr: 3.1623e-05
# Learning rate:  9.999999e-06
# Epoch 19/40
# 206/206 [==============================] - ETA: 0s - loss: 0.4303 - accuracy: 0.8756
# Epoch 00019: val_accuracy did not improve from 0.85417
# 206/206 [==============================] - 42s 203ms/step - loss: 0.4303 - accuracy: 0.8756 - val_loss: 1.7418 - val_accuracy: 0.8333 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 20/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3393 - accuracy: 0.9053
# Epoch 00020: val_accuracy did not improve from 0.85417
# 206/206 [==============================] - 40s 195ms/step - loss: 0.3393 - accuracy: 0.9053 - val_loss: 1.2523 - val_accuracy: 0.8542 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 21/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8932
# Epoch 00021: val_accuracy did not improve from 0.85417
# 206/206 [==============================] - 41s 199ms/step - loss: 0.3759 - accuracy: 0.8932 - val_loss: 1.9310 - val_accuracy: 0.8125 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 22/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3443 - accuracy: 0.9001
# Epoch 00022: val_accuracy did not improve from 0.85417
# 206/206 [==============================] - 41s 198ms/step - loss: 0.3443 - accuracy: 0.9001 - val_loss: 2.1094 - val_accuracy: 0.8333 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 23/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3275 - accuracy: 0.8987
# Epoch 00023: val_accuracy improved from 0.85417 to 0.86458, saving model to dog_breed_classifier.h5
# 206/206 [==============================] - 44s 212ms/step - loss: 0.3275 - accuracy: 0.8987 - val_loss: 1.6831 - val_accuracy: 0.8646 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 24/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3286 - accuracy: 0.9019
# Epoch 00024: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 41s 200ms/step - loss: 0.3286 - accuracy: 0.9019 - val_loss: 2.1540 - val_accuracy: 0.8438 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 25/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3080 - accuracy: 0.9138
# Epoch 00025: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 40s 197ms/step - loss: 0.3080 - accuracy: 0.9138 - val_loss: 1.7355 - val_accuracy: 0.7917 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 26/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.9120
# Epoch 00026: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 41s 197ms/step - loss: 0.3099 - accuracy: 0.9120 - val_loss: 2.1119 - val_accuracy: 0.8646 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 27/40
# 206/206 [==============================] - ETA: 0s - loss: 0.3160 - accuracy: 0.9084
# Epoch 00027: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 41s 201ms/step - loss: 0.3160 - accuracy: 0.9084 - val_loss: 3.1964 - val_accuracy: 0.8333 - lr: 1.0000e-05
# Learning rate:  9.999999e-06
# Epoch 28/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2731 - accuracy: 0.9150
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 3.162277292675049e-06.
#
# Epoch 00028: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 41s 200ms/step - loss: 0.2731 - accuracy: 0.9150 - val_loss: 3.6309 - val_accuracy: 0.7812 - lr: 1.0000e-05
# Learning rate:  3.1622774e-06
# Epoch 29/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2843 - accuracy: 0.9172
# Epoch 00029: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 42s 204ms/step - loss: 0.2843 - accuracy: 0.9172 - val_loss: 2.5145 - val_accuracy: 0.8438 - lr: 3.1623e-06
# Learning rate:  3.1622774e-06
# Epoch 30/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2764 - accuracy: 0.9254
# Epoch 00030: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 41s 201ms/step - loss: 0.2764 - accuracy: 0.9254 - val_loss: 2.5910 - val_accuracy: 0.8438 - lr: 3.1623e-06
# Learning rate:  3.1622774e-06
# Epoch 31/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.9211
# Epoch 00031: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 43s 208ms/step - loss: 0.2627 - accuracy: 0.9211 - val_loss: 2.3053 - val_accuracy: 0.8542 - lr: 3.1623e-06
# Learning rate:  3.1622774e-06
# Epoch 32/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2644 - accuracy: 0.9260
# Epoch 00032: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 43s 210ms/step - loss: 0.2644 - accuracy: 0.9260 - val_loss: 2.1880 - val_accuracy: 0.8333 - lr: 3.1623e-06
# Learning rate:  3.1622774e-06
# Epoch 33/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2689 - accuracy: 0.9272
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 9.999999115286567e-07.
#
# Epoch 00033: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 42s 204ms/step - loss: 0.2689 - accuracy: 0.9272 - val_loss: 2.3748 - val_accuracy: 0.8438 - lr: 3.1623e-06
# Learning rate:  9.999999e-07
# Epoch 34/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2512 - accuracy: 0.9235
# Epoch 00034: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 43s 210ms/step - loss: 0.2512 - accuracy: 0.9235 - val_loss: 1.6982 - val_accuracy: 0.8333 - lr: 1.0000e-06
# Learning rate:  9.999999e-07
# Epoch 35/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2658 - accuracy: 0.9229
# Epoch 00035: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 43s 209ms/step - loss: 0.2658 - accuracy: 0.9229 - val_loss: 2.0695 - val_accuracy: 0.8333 - lr: 1.0000e-06
# Learning rate:  9.999999e-07
# Epoch 36/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2692 - accuracy: 0.9254
# Epoch 00036: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 43s 208ms/step - loss: 0.2692 - accuracy: 0.9254 - val_loss: 1.9623 - val_accuracy: 0.8646 - lr: 1.0000e-06
# Learning rate:  9.999999e-07
# Epoch 37/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2396 - accuracy: 0.9287
# Epoch 00037: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 42s 204ms/step - loss: 0.2396 - accuracy: 0.9287 - val_loss: 1.7675 - val_accuracy: 0.8542 - lr: 1.0000e-06
# Learning rate:  9.999999e-07
# Epoch 38/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2748 - accuracy: 0.9272
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.1622772926750485e-07.
#
# Epoch 00038: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 43s 210ms/step - loss: 0.2748 - accuracy: 0.9272 - val_loss: 1.5495 - val_accuracy: 0.8646 - lr: 1.0000e-06
# Learning rate:  3.1622773e-07
# Epoch 39/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2547 - accuracy: 0.9223
# Epoch 00039: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 43s 209ms/step - loss: 0.2547 - accuracy: 0.9223 - val_loss: 3.0934 - val_accuracy: 0.8229 - lr: 3.1623e-07
# Learning rate:  3.1622773e-07
# Epoch 40/40
# 206/206 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9387
# Epoch 00040: val_accuracy did not improve from 0.86458
# 206/206 [==============================] - 42s 206ms/step - loss: 0.2224 - accuracy: 0.9387 - val_loss: 1.8310 - val_accuracy: 0.8333 - lr: 3.1623e-07
# CPU times: user 43min 51s, sys: 2min 19s, total: 46min 10s
# Wall time: 28min 59s

# %%
plt.rcParams["figure.figsize"] = [20,10]
plt.subplot(2, 1, 1)
plt.title('Training and test accuracy')
plt.plot(params.epoch, params.history['accuracy'], label='Training accuracy')
plt.plot(params.epoch, params.history['val_accuracy'], label='Test accuracy')
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.title('Training and test loss')
plt.plot(params.epoch, params.history['loss'], label='Training loss')
plt.plot(params.epoch, params.history['val_loss'], label='Test loss')
plt.legend()
plt.grid(True)

plt.show()
